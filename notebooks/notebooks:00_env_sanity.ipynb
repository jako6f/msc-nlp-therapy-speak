# %%
print("Hello world wohoo")
# Out:
# Hello world wohoo

# %%
import sys
import platform

print("Python version:")
print(sys.version)

print("\nPython executable (this tells you WHICH env is running):")
print(sys.executable)

print("\nPlatform:")
print(platform.platform())
# Out:
# Python version:
# 3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, 11:23:37) [Clang 14.0.6 ]
#
# Python executable (this tells you WHICH env is running):
# /opt/anaconda3/envs/msc-nlp/bin/python
#
# Platform:
# macOS-15.5-arm64-arm-64bit-Mach-O
